# %% [markdown]
# # **Chains**

# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq

load_dotenv()

llm = ChatGroq(temperature=0.7, model="llama-3.3-70b-versatile", api_key=os.getenv("GROQ_API_KEY"))

# %% [markdown]
# # First Chain

# %%
# task - 1 [prompt]

from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant that provides information about countries."),
    ("human", "{input}")
])

# %%
# task - 2 [LLM]

llm = ChatGroq(temperature=0.7, model="llama-3.3-70b-versatile", api_key=os.getenv("GROQ_API_KEY"))

# %%
# task - 3 [Str parser]

from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

# %% [markdown]
# ### Manual Invocation

# %%
template = prompt_template.invoke({"input":"Tell me about Sri Lanka"})

res = llm.invoke(template)

final_res = res.content

final_res
# Out:
# 'Sri Lanka, officially known as the Democratic Socialist Republic of Sri Lanka, is an island nation located in the Indian Ocean, off the coast of India. It is a country with a rich history, diverse culture, and breathtaking natural beauty. Here are some interesting facts about Sri Lanka:\n\n**Geography and Climate:**\nSri Lanka is an island with a total area of approximately 65,610 square kilometers (25,332 square miles). It is separated from India by the Gulf of Mannar and the Palk Strait. The country has a tropical climate, with two main seasons: the dry season (December to April) and the wet season (May to November). The central highlands are cooler, while the coastal regions are warmer and more humid.\n\n**History and Culture:**\nSri Lanka has a long and storied history, dating back to the 5th century BCE. The country was a major center of Buddhism and was influenced by various cultures, including Indian, Chinese, and European. The ancient city of Anuradhapura is a UNESCO World Heritage Site and features numerous ruins and artifacts from the ancient kingdom. Sri Lankan culture is a unique blend of Buddhist, Hindu, Muslim, and Christian traditions, with a strong emphasis on family, community, and respect for elders.\n\n**Economy and Infrastructure:**\nSri Lanka has a developing economy, with a mix of agriculture, manufacturing, and services. The country is a major producer of tea, rubber, and spices, and has a growing tourism industry. The capital city, Colombo, is a bustling metropolis with modern infrastructure, including a international airport, seaport, and a well-connected transportation network.\n\n**Places to Visit:**\nSri Lanka is a popular tourist destination, with many attractions to explore:\n\n1. **Sigiriya Rock Fortress:** A ancient rock fortress and UNESCO World Heritage Site, featuring stunning views and ancient ruins.\n2. **Kandy:** A cultural and spiritual hub, known for its Temple of the Tooth, a sacred Buddhist site.\n3. **Mirissa:** A beautiful beach town on the south coast, popular for whale watching and surfing.\n4. **Yala National Park:** A wildlife sanctuary and home to elephants, leopards, and sloth bears.\n5. **Galle Fort:** A historic fort city and UNESCO World Heritage Site, with a rich colonial history.\n\n**Cuisine:**\nSri Lankan cuisine is a delicious blend of Indian, Chinese, and Middle Eastern flavors, with a focus on fresh seafood, spices, and rice. Popular dishes include:\n\n1. **Rice and Curry:** A staple meal, featuring a variety of curries and side dishes.\n2. **Hoppers:** Thin, crispy pancakes made from rice flour and coconut milk.\n3. **String Ho
ka is home to eight UNESCO World Heritage Sites, including the ancient cities of Anuradhapura and Polonnaruwa.\n2. The country has a high literacy rate, with over 90% of the population able to read and write.\n3. Sri Lanka is a popular destination for surfers, with consistent waves and warm waters.\n4. The country has a vibrant festival calendar, with the Esala Perahera (a Buddhist festival) being one of the most famous.\n\nI hope this gives you a good introduction to Sri Lanka! Do you have any specific questions or would you like to know more about a particular aspect of the country?"

# %%
from langchain_core.runnables import RunnableSequence

chain_1 = RunnableSequence(prompt_template, llm, parser)

chain_1.invoke({"input":"Tell me about Sri Lanka"})
# Out:
# "Sri Lanka! A beautiful island nation located in the Indian Ocean, off the coast of India. Here's an overview:\n\n** Geography and Climate **\n\nSri Lanka, formerly known as Ceylon, is an island country with a total area of approximately 65,610 square kilometers (25,332 square miles). It is separated from India by the Gulf of Mannar and the Palk Strait. The country has a diverse geography, with tropical rainforests, mountains, and beautiful beaches along its coast. The climate is tropical, with two main seasons: the dry season (December to April) and the wet season (May to November).\n\n** Culture and History **\n\nSri Lanka has a rich cultural heritage, with a history dating back over 3,000 years. The country is home to several ancient civilizations, including the Sinhalese, Tamils, and Muslims. Buddhism is the dominant religion, and the country is home to many ancient Buddhist temples and ruins, including the famous city of Anuradhapura. The country was a British colony from 1815 to 1948, and as a result, English is widely spoken.\n\n** Economy and Tourism **\n\nSri Lanka has a growing economy, with a mix of industries such as textiles, tea, and tourism. The country is known for its beautiful beaches, ancient ruins, and vibrant culture, making it a popular tourist destination. The capital city, Colombo, is a bustling metropolis with a mix of modern and colonial architecture. Other popular tourist destinations include Kandy, Galle, and Nuwara Eliya.\n\n** Cuisine **\n\nSri Lankan cuisine is a delicious blend of Indian, Chinese, and Middle Eastern flavors. Popular dishes include rice and curry, hoppers (thin pancakes), string hoppers (steamed rice noodles), and lamprais (a Dutch-influenced dish made with meat, rice, and spices). The country is also famous for its tea, with Ceylon tea being a popular export.\n\n** Interesting Facts **\n\n* Sri Lanka is home to eight UNESCO World Heritage Sites, including the ancient cities of Anuradhapura and Polonnaruwa.\n* The country has a high level of biodiversity, with many endemic species found nowhere else in the world.\n* Sri Lanka is one of the few countries in the world where you can see blue whales, sperm whales, and dolphins in their natural habitat.\n* The country has a vibrant festival culture, with the Esala Perahera (a Buddhist festival) being one of the most famous.\n\n** Challenges and Opportunities **\n\nSri Lanka has faced several challenges in recent years, including a civil war that ended in 2009 and a devastating tsunami in 2004. However, the country is rebuilding and growing, with a focus on tourism, infrastructure development, and economic growth. The country has also made significant progress in areas such as education and healthcare.\n\nOverall, Sri Lanka is a beautiful and fascinating country, with a rich culture, stunning natural beauty, and a warm and welcoming people. Whether you're interested in history, culture, nature, or simply relaxing on a beautiful beach, Sri Lanka has something to offer."
